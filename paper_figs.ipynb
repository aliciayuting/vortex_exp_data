# %% [markdown]
# ## throughput vs. latency for micro 4 node with Vortex

# %%
node_hr = 4.352

micro_TP    =   [53.759, 64.264, 73.862, 81.182, 90.32, 99.049, 109.088, 112.712, 116.009]
mono_TP     =   [53.832,	64.151,	73.791,	80.853,	90.256,	98.535,	104.805]
sendrate = [55,	65,	75,	85,	95,	105,	115,	120,	125]

micro_QPH = [a*3600 for a in micro_TP]
mono_QPH = [b*3600 for b in mono_TP]
micro_cpq = [node_hr/x for x in micro_QPH]
mono_cpq = [node_hr/y for y in mono_QPH]
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(sendrate, micro_cpq, color='red', marker='o', linestyle='-', label="Microservices")
# plt.plot(sendrate, mono_cpq, color='green', marker='o', linestyle='-', label="Monolithic")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Cost per query ($)")
plt.title("Cost Per Query: Micro vs. Mono deployment on $\mathbf{Vortex}$ with 4 nodes")
plt.grid(True)
plt.legend()
plt.savefig('./cpq_microVSmono_cluster4vortex.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
micro_TP    =   [53.759, 64.264, 73.862, 81.182, 90.32, 99.049, 109.088, 112.712, 116.009]
micro_med   =   [65.123,66.872,67.467, 68.36, 74.462, 102.393, 179.1, 210.394, 441.16]
micro_p95   =   [70.291,	73.48,	74.064,	80.674,	107.953,	153.032,	282.595,	362.99,	1212.222]

mono_TP     =   [53.832,	64.151,	73.791,	80.853,	90.256,	98.535,	104.805]
mono_med    =   [57.883,	57.744,	103.618,	105.137,	180.126,	401.02,	1050.134]
mono_p95    =   [60.544,	60.311,	149.258,	152.998,	242.034,	529.013,	1724.003]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(micro_TP, micro_med, color='red', marker='o', linestyle='-', label="Microservices median")
plt.plot(mono_TP, mono_med, color='green', marker='o', linestyle='-', label="Monolithic median")

plt.plot(micro_TP, micro_p95, color='red', marker='v', linestyle='--', label="Microservices p95")
plt.plot(mono_TP, mono_p95, color='green', marker='v', linestyle='--', label="Monolithic p95")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Latency (ms)")
plt.title("Latency Comparison: Micro vs. Mono deployment on $\mathbf{Vortex}$ with 4 nodes")
plt.grid(True)
plt.legend()

plt.savefig('./latency_microVSmono_cluster4vortex.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## throughput vs. latency for micro 4 node with Ray

# %% [markdown]
# ##

# %%
micro_TP = [30.41,	50.52,	58.74,	66.66,	74.25,	81.69,	88.39,	95.1,		100.87,	106.23,	104.68]
micro_med = [93,	113,	126,	146,	179,	211,	296,	306,		390,	555,	2455]
micro_p95 = [102,	177,	209,	250,	353,	573,	792,	761,		858,	1132,	5869]

mono_TP     = [30.44,	50.42,	58.51,	66.46,	73.77,	80.67,	86.42,	86.92,	85.86]
mono_med    = [63,	69,	104,	141,	182,	266,	345,	414,	427]
mono_p95    = [103,	180,	236,	288,	352,	401,	452,	546,	584]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(micro_TP[:-1], micro_med[:-1], color='orange', marker='o', linestyle='-', label="Microservices median")
plt.plot(mono_TP[:-1], mono_med[:-1], color='blue', marker='o', linestyle='-', label="Monolithic median")

plt.plot(micro_TP[:-1], micro_p95[:-1], color='orange', marker='v', linestyle='--', label="Microservices p95")
plt.plot(mono_TP[:-1], mono_p95[:-1], color='blue', marker='v', linestyle='--', label="Monolithic p95")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Latency (ms)")
plt.title("Latency Comparison: Micro vs. Mono deployment on $\mathbf{Ray}$ with 4 nodes")
plt.grid(True)
plt.legend()

plt.savefig('./latency_microVSmono_cluster4ray.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
node_hr = 4.352

micro_QPH = [a*3600 for a in micro_TP]
mono_QPH = [b*3600 for b in mono_TP]
micro_cpq = [node_hr/x for x in micro_QPH]
mono_cpq = [node_hr/y for y in mono_QPH]
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(micro_TP, micro_cpq, color='orange', marker='o', linestyle='-', label="Microservices")
plt.plot(mono_TP, mono_cpq, color='blue', marker='o', linestyle='-', label="Monolithic")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Cost per query ($)")
plt.title("Cost Per Query: Micro vs. Mono deployment on $\mathbf{Ray}$ with 4 nodes")
plt.grid(True)
plt.legend()
plt.savefig('./cpq_microVSmono_cluster4ray.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### TP vs Lat cluster 7 Vortex

# %%
node_hr = 4.352

micro_TP    = [61.983,	131.805,	147.187,	163.943,	179.32,	202.797,	215.659,	218.033,	217.752,	215.651]
mono_TP     = [31.715,	130.614,	147.562,	163.303,	178.377,	181.969,	182.228]

micro_QPH = [a*3600 for a in micro_TP]
mono_QPH = [b*3600 for b in mono_TP]
micro_cpq = [node_hr/x for x in micro_QPH]
mono_cpq = [node_hr/y for y in mono_QPH]
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(micro_TP[:-2], micro_cpq[:-2], color='red', marker='o', linestyle='-', label="Microservices")
plt.plot(mono_TP[:-2], mono_cpq[:-2], color='green', marker='o', linestyle='-', label="Monolithic")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Cost per query ($)")
plt.title("Cost Per Query: Micro vs. Mono deployment on $\mathbf{Vortex}$ with 7 nodes")
plt.grid(True)
plt.legend()
plt.savefig('./cpq_microVSmono_cluster7vortex.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
micro_TP    = [61.983,	131.805,	147.187,	163.943,	179.32,	202.797,	215.659,	218.033,	217.752,	215.651]
micro_med   = [69.949,	69.182,	69.275,	98,	119.988,	365.897,	549.633,	1734.611,	1902.142,	2382.035]
micro_p95   = [79.133,	79.715,	81.957,	155.555,157.413	,480.464,	812.796,	2703.697,	2913.155,	3922.299]

mono_TP     = [31.715,	94.789,	130.614,	147.562,	163.303,	178.377,	181.969,	182.228]
mono_med    = [75.178,	57.821,	105.227,	141.165,	260.555,	529.825,	1575.772,	2830.595]
mono_p95    = [82.561,	60.791,	152.574,	189.121,	425.181,	789.211,	2775.171,	4794.318]

# %%
plt.figure(figsize=(8, 6))
plt.plot(micro_TP[:-2], micro_med[:-2], color='red', marker='o', linestyle='-', label="Microservices median")
plt.plot(mono_TP[:-2], mono_med[:-2], color='green', marker='o', linestyle='-', label="Monolithic median")

plt.plot(micro_TP[:-2], micro_p95[:-2], color='red', marker='v', linestyle='--', label="Microservices p95")
plt.plot(mono_TP[:-2], mono_p95[:-2], color='green', marker='v', linestyle='--', label="Monolithic p95")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Latency (ms)")
plt.title("Latency Comparison: Micro vs. Mono deployment on $\mathbf{Vortex}$ with 7 nodes")
plt.grid(True)
plt.legend()

plt.savefig('./latency_microVSmono_cluster7vortex.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
node_hr = 4.352

micro_TP    = [58,	114.07,	127.09,	138.15,	170.72,	184.81,	196.6,	209.73,	214.22,	197.86]
mono_TP     = [30.44,	85.62,	112.45,	124.75,	135.66,	144.55,	152.14,	148.39]


micro_QPH = [a*3600 for a in micro_TP]
mono_QPH = [b*3600 for b in mono_TP]
micro_cpq = [node_hr/x for x in micro_QPH]
mono_cpq = [node_hr/y for y in mono_QPH]
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(micro_TP, micro_cpq, color='blue', marker='o', linestyle='-', label="Microservices")
plt.plot(mono_TP, mono_cpq, color='orange', marker='o', linestyle='-', label="Monolithic")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Cost per query ($)")
plt.title("Cost Per Query: Micro vs. Mono deployment on $\mathbf{Ray}$ with 7 nodes")
plt.grid(True)
plt.legend()
plt.savefig('./cpq_microVSmono_cluster7ray.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
micro_TP    = [58,	114.07,	127.09,	138.15,	170.72,	184.81,	196.6,	209.73,	214.22,	197.86]
micro_med   = [104,	156,	178,	206,	312,	428,	595,	788,	1019,	3183.5]
micro_p95   = [151,	334,	389,	566,	666,	843,	1040,	1185,	1419,	8059]

mono_TP     = [30.44,	85.62,	112.45,	124.75,	135.66,	144.55,	152.14,	148.39]
mono_med    = [65,	68,	115,	150,	231,	299,	347,	427]
mono_p95    = [83,	189,	310,	351,	406,	427,	480,	518]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(micro_TP, micro_med, color='orange', marker='o', linestyle='-', label="Microservices median")
plt.plot(mono_TP, mono_med, color='blue', marker='o', linestyle='-', label="Monolithic median")

plt.plot(micro_TP, micro_p95, color='orange', marker='v', linestyle='--', label="Microservices p95")
plt.plot(mono_TP, mono_p95, color='blue', marker='v', linestyle='--', label="Monolithic p95")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Latency (ms)")
plt.title("Latency Comparison: Micro vs. Mono deployment on $\mathbf{Ray}$ with 7 nodes")
plt.grid(True)
plt.legend()

plt.savefig('./latency_microVSmono_cluster7ray.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(micro_TP[:-1], micro_med[:-1], color='orange', marker='o', linestyle='-', label="Microservices median")
plt.plot(mono_TP[:-1], mono_med[:-1], color='blue', marker='o', linestyle='-', label="Monolithic median")

plt.plot(micro_TP[:-1], micro_p95[:-1], color='orange', marker='v', linestyle='--', label="Microservices p95")
plt.plot(mono_TP[:-1], mono_p95[:-1], color='blue', marker='v', linestyle='--', label="Monolithic p95")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Latency (ms)")
plt.title("Latency Comparison: Micro vs. Mono deployment on $\mathbf{Ray}$ with 7 nodes")
plt.grid(True)
plt.legend()

plt.savefig('./latency_microVSmono_cluster7ray.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
vmicro_tcp_tp = [46.711,	54.738,	61.445,	66.881,	73.841,	77.168,	84.173,	91.346,	99.538,	99.448]
vmicro_tcp_me = [80.393,	84.983,	92.428,	91.644,	113.859,	94.342,	186.427,		138.827,	193.189,	1401.428]
vmicro_tcp_95 = [88.418,	97.258,	156.378,	133.129,	197.613,	130.792,	243.276,	240.466,	325.451,	2616.224]



vmicro_TP    =   [53.759, 64.264, 73.862, 81.182, 90.32, 99.049, 109.088, 112.712, 116.009]
vmicro_med   =   [65.123,66.872,67.467, 68.36, 74.462, 102.393, 179.1, 210.394, 441.16]
vmicro_p95   =   [70.291,	73.48,	74.064,	80.674,	107.953,	153.032,	282.595,	362.99,	1212.222]


rmicro_TP = [30.41,	50.52,	58.74,	66.66,	74.25,	81.69,	88.39,	95.1,		100.87,	106.23,	104.68]
rmicro_med = [93,	113,	126,	146,	179,	211,	296,	306,		390,	555,	2455]
rmicro_p95 = [102,	177,	209,	250,	353,	573,	792,	761,		858,	1132,	5869]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 9))
plt.plot(vmicro_tcp_tp, vmicro_tcp_me,  color='brown',  marker='o', linestyle='-', linewidth=3, label="Vortex w. TCP median")
plt.plot(vmicro_TP,     vmicro_med,     color='red',    marker='o', linestyle='-', linewidth=3, label="Vortex w. RDMA median")
plt.plot(rmicro_TP,     rmicro_med,     color='green',  marker='v', linestyle='-', linewidth=3, label="Ray w. TCP median")
plt.xlabel("System Throughput (QPS)",fontsize=22)
plt.ylabel("Latency (ms)",fontsize=22)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
# plt.grid(True)
plt.legend(fontsize=22)
plt.savefig('paper_plots/medlatency_comparison_vortex_ray_tcp_rdma.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 9))
plt.plot(vmicro_tcp_tp, vmicro_tcp_95,  color='brown',  marker='o', linestyle='-', linewidth=3, label="Vortex w. TCP p95")
plt.plot(vmicro_TP,     vmicro_p95,     color='red',    marker='o', linestyle='-', linewidth=3, label="Vortex w. RDMA p95")
plt.plot(rmicro_TP,     rmicro_p95,     color='green',  marker='v', linestyle='-', linewidth=3, label="Ray w. TCP p95")
plt.xlabel("System Throughput (QPS)",fontsize=22)
plt.ylabel("Latency (ms)",fontsize=22)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
plt.savefig('paper_plots/p95latency_comparison_vortex_ray_tcp_rdma.pdf', dpi=300, bbox_inches='tight')
plt.legend(fontsize=22)
plt.show()

# %%
import numpy as np

# %% [markdown]
# ## Step [A,B,C,D] LT, TP vs. BS, WITHOUT MIG!!!

# %%
A_BS = [4,8,16,32,64,128]
A_LT = [10072938,10794654,12093455,14909036,20113986,30901977]
A_TP = [385.2513271,712.7262088,936.2189526,963.8542515,1012.842756,1102.254335]
A_ME = [881,1113,1361,2029,3309,5677]
A_UT = [53,77,81,82,83,88]
A_UT = np.array(A_UT) / 100

B_BS = [1,4,8,16]
B_LT= [30577346,98450055,183342747,349656199]
B_TP = [32.70394993,40.62973838,43.63412313,45.75923445]
B_ME = [2773,6861,11655,20919]
B_UT = [86,89,92,100]
B_UT = np.array(B_UT) / 100

C_BS = [1,2,4,8,16,32]
C_LT = [68343,78050,77584,100704,210544,255132]
C_TP = [480.9264079,517.7125569,531.6332203,553.7214044,544.7724817,536.8632138]

D_BS = [1,2,4,8,16,32]
D_LT = [1676375,1775429,1775816,1928968,2353222,2854471]
D_TP = [215.0265148,245.0789758,263.47088,271.7584108,277.9841824,279.4603766]

E_BS = [1,4,8,16,32,64,128,256]
E_LT = [17742194,63661381,114005396,209285099,464184367,856201530,1726852009,3466210119]
E_TP = [55.6452441,62.37067675,69.71045999,75.96718568,68.54270783,74.41683093,73.81478001,73.3154351]
E_ME = [777,787,765,777,775,783,795,885]
E_UT = [42,42,44,45,44,44,46,42]
E_UT = np.array(E_UT) / 100

# %%
plt.figure(figsize=(15, 10))
plt.plot(A_BS[:-2], np.array(A_LT[:-2]) / (10**6) , linewidth=3, color='orange', marker='o', linestyle='-', label="Text Encoder")
plt.plot(B_BS, np.array(B_LT) / (10**6) , linewidth=3, color='red', marker='v', linestyle='-', label="Vision Encoder")
# plt.plot(C_BS, np.array(C_LT) / (10**6) , color='blue', marker='v', linestyle='-', label="Step C")
plt.plot(D_BS, np.array(D_LT) / (10**6) , linewidth=3, color='green', marker='s', linestyle='-', label="Cross Attention")
plt.plot(E_BS[:-3], np.array(E_LT[:-3]) / (10**6) , linewidth=3, color='brown', marker='v', linestyle='-', label="ColBERT search")
plt.xlabel("Batch Size",fontsize=22)
plt.ylabel("Latency (ms)",fontsize=22)
plt.yscale('log')  # Use logarithmic scale for better visualization of differences
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)

plt.legend(fontsize=20, loc='upper left', bbox_to_anchor=(-0.3, 1.0), borderaxespad=0.)
plt.savefig("paper_plots/ppl1_steps_latency.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(A_BS[:-2], np.array(A_TP[:-2]) , linewidth=3, color='orange', marker='o', linestyle='-', label="Step A")
plt.plot(B_BS, np.array(B_TP) , linewidth=3, color='red', marker='v', linestyle='-', label="Step B")
# plt.plot(C_BS, np.array(C_TP) , color='blue', marker='v', linestyle='-', label="Step C")
plt.plot(D_BS, np.array(D_TP)  , linewidth=3, color='green', marker='s', linestyle='-', label="Step D")
plt.plot(E_BS[:-3], np.array(E_TP[:-3]) , linewidth=3, color='brown', marker='v', linestyle='-', label="Step E")
plt.xlabel("Batch Size",fontsize=22)
plt.ylabel("Throughput (QPS)",fontsize=22)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
# plt.title("Throughput Comparison of Different Steps in the Pipeline")
# plt.grid(True)
# plt.legend(fontsize=36)
plt.savefig("paper_plots/ppl1_steps_throughput.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(A_BS[:-2], A_UT[:-2] * 100 , linewidth=3, color='orange', marker='o', linestyle='-', label="Text Encoder")
plt.plot(B_BS,      B_UT * 100 , linewidth=3, color='red', marker='v', linestyle='-', label="Vision Encoder")
# plt.plot(C_BS, np.array(C_LT) / (10**6) , color='blue', marker='v', linestyle='-', label="Step C")
# plt.plot(D_BS, np.array(D_LT) / (10**6) , linewidth=3, color='green', marker='s', linestyle='-', label="Cross Attention")
plt.plot(E_BS[:-3], E_UT[:-3]*100 , linewidth=3, color='brown', marker='v', linestyle='-', label="ColBERT search")
plt.xlabel("Batch Size",fontsize=22)
plt.ylabel("GPU Utilization (%)",fontsize=22)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)

# plt.legend(fontsize=20, loc='upper left', bbox_to_anchor=(-0.3, 1.0), borderaxespad=0.)
plt.savefig("paper_plots/ppl1_steps_utl.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(A_BS[:-2], A_ME[:-2] , linewidth=3, color='orange', marker='o', linestyle='-', label="Text Encoder")
plt.plot(B_BS,      B_ME , linewidth=3, color='red', marker='v', linestyle='-', label="Vision Encoder")
# plt.plot(C_BS, np.array(C_LT) / (10**6) , color='blue', marker='v', linestyle='-', label="Step C")
# plt.plot(D_BS, np.array(D_LT) / (10**6) , linewidth=3, color='green', marker='s', linestyle='-', label="Cross Attention")
plt.plot(E_BS[:-3], E_ME[:-3] , linewidth=3, color='brown', marker='v', linestyle='-', label="ColBERT search")
plt.xlabel("Batch Size",fontsize=22)
plt.ylabel("GPU Memory (MiB)",fontsize=22)
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
plt.yscale('log')
# plt.legend(fontsize=20, loc='upper left', bbox_to_anchor=(-0.3, 1.0), borderaxespad=0.)
plt.savefig("paper_plots/ppl1_steps_mem.pdf", dpi=300, bbox_inches='tight')
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,7))
# Plot on the left y-axis
color = 'tab:red'
ax1.set_xlabel('Batch size', fontsize=26)
ax1.set_ylabel('Latency (ms)', color=color, fontsize=26)
ax1.plot(A_BS, np.array(A_LT) / (10**6), color=color)
ax1.tick_params(axis='y', labelcolor=color, labelsize=26)  # Set the tick parameters for the left y-axis
ax1.tick_params(axis='x', labelsize=26)
ax1.set_ylim(0, 100)
# Create a second y-axis that shares the same x-axis
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Throughput', color=color, fontsize=26)
ax2.plot(A_BS, A_TP, color=color)
ax2.tick_params(axis='y', labelcolor=color, labelsize=26)
ax2.set_ylim(0, 1200)
# Adjust layout to prevent clipping of labels
fig.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# ## stepB

# %%
fig, ax1 = plt.subplots(figsize=(10,7))
# Plot on the left y-axis
color = 'tab:red'
ax1.set_xlabel('Batch size', fontsize=26)
ax1.set_ylabel('Latencies (ms)', color=color, fontsize=26)
ax1.plot(B_BS, B_LT, color=color)
ax1.tick_params(axis='y', labelcolor=color, labelsize=26)  # Set the tick parameters for the left y-axis
ax1.tick_params(axis='x', labelsize=26)
# Create a second y-axis that shares the same x-axis
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Throughput', color=color, fontsize=26)
ax2.plot(B_BS, B_TP, color=color)
ax2.tick_params(axis='y', labelcolor=color, labelsize=26)

# Adjust layout to prevent clipping of labels
fig.tight_layout()

# Display the plot
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,7))
# Plot on the left y-axis
color = 'tab:red'
ax1.set_xlabel('Batch size', fontsize=26)
ax1.set_ylabel('Latencies (ms)', color=color, fontsize=26)
ax1.plot(C_BS, C_LT, color=color)
ax1.tick_params(axis='y', labelcolor=color, labelsize=26)  # Set the tick parameters for the left y-axis
ax1.tick_params(axis='x', labelsize=26)
# Create a second y-axis that shares the same x-axis
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Throughput', color=color, fontsize=26)
ax2.plot(C_BS, C_TP, color=color)
ax2.tick_params(axis='y', labelcolor=color, labelsize=26)

# Adjust layout to prevent clipping of labels
fig.tight_layout()

# Display the plot
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,7))
# Plot on the left y-axis
color = 'tab:red'
ax1.set_xlabel('Batch size', fontsize=26)
ax1.set_ylabel('Latencies (ms)', color=color, fontsize=26)
ax1.plot(D_BS, D_LT, color=color)
ax1.tick_params(axis='y', labelcolor=color, labelsize=26)  # Set the tick parameters for the left y-axis
ax1.tick_params(axis='x', labelsize=26)
# Create a second y-axis that shares the same x-axis
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Throughput', color=color, fontsize=26)
ax2.plot(D_BS, D_TP, color=color)
ax2.tick_params(axis='y', labelcolor=color, labelsize=26)

# Adjust layout to prevent clipping of labels
fig.tight_layout()

# Display the plot
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,7))
# Plot on the left y-axis
color = 'tab:red'
ax1.set_xlabel('Batch size', fontsize=26)
ax1.set_ylabel('Latencies (ms)', color=color, fontsize=26)
ax1.plot(E_BS, E_LT, color=color)
ax1.tick_params(axis='y', labelcolor=color, labelsize=26)  # Set the tick parameters for the left y-axis
ax1.tick_params(axis='x', labelsize=26)
# Create a second y-axis that shares the same x-axis
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Throughput', color=color, fontsize=26)
ax2.plot(E_BS, E_TP, color=color)
ax2.tick_params(axis='y', labelcolor=color, labelsize=26)

# Adjust layout to prevent clipping of labels
fig.tight_layout()

# Display the plot
plt.show()
