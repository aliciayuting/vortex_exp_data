# %% [markdown]
# ## throughput vs. latency for micro 4 node with Vortex

# %%
node_hr = 4.352

micro_TP    =   [53.759, 64.264, 73.862, 81.182, 90.32, 99.049, 109.088, 112.712, 116.009]
mono_TP     =   [53.832,	64.151,	73.791,	80.853,	90.256,	98.535,	104.805]
sendrate = [55,	65,	75,	85,	95,	105,	115,	120,	125]

micro_QPH = [a*3600 for a in micro_TP]
mono_QPH = [b*3600 for b in mono_TP]
micro_cpq = [node_hr/x for x in micro_QPH]
mono_cpq = [node_hr/y for y in mono_QPH]
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(sendrate, micro_cpq, color='red', marker='o', linestyle='-', label="Microservices")
# plt.plot(sendrate, mono_cpq, color='green', marker='o', linestyle='-', label="Monolithic")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Cost per query ($)")
plt.title("Cost Per Query: Micro vs. Mono deployment on $\mathbf{Vortex}$ with 4 nodes")
plt.grid(True)
plt.legend()
plt.savefig('./cpq_microVSmono_cluster4vortex.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
micro_TP    =   [53.759, 64.264, 73.862, 81.182, 90.32, 99.049, 109.088, 112.712, 116.009]
micro_med   =   [65.123,66.872,67.467, 68.36, 74.462, 102.393, 179.1, 210.394, 441.16]
micro_p95   =   [70.291,	73.48,	74.064,	80.674,	107.953,	153.032,	282.595,	362.99,	1212.222]

mono_TP     =   [53.832,	64.151,	73.791,	80.853,	90.256,	98.535,	104.805]
mono_med    =   [57.883,	57.744,	103.618,	105.137,	180.126,	401.02,	1050.134]
mono_p95    =   [60.544,	60.311,	149.258,	152.998,	242.034,	529.013,	1724.003]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(micro_TP, micro_med, color='red', marker='o', linestyle='-', label="Microservices median")
plt.plot(mono_TP, mono_med, color='green', marker='o', linestyle='-', label="Monolithic median")

plt.plot(micro_TP, micro_p95, color='red', marker='v', linestyle='--', label="Microservices p95")
plt.plot(mono_TP, mono_p95, color='green', marker='v', linestyle='--', label="Monolithic p95")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Latency (ms)")
plt.title("Latency Comparison: Micro vs. Mono deployment on $\mathbf{Vortex}$ with 4 nodes")
plt.grid(True)
plt.legend()

plt.savefig('./latency_microVSmono_cluster4vortex.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## throughput vs. latency for micro 4 node with Ray

# %% [markdown]
# ##

# %%
micro_TP = [30.41,	50.52,	58.74,	66.66,	74.25,	81.69,	88.39,	95.1,		100.87,	106.23,	104.68]
micro_med = [93,	113,	126,	146,	179,	211,	296,	306,		390,	555,	2455]
micro_p95 = [102,	177,	209,	250,	353,	573,	792,	761,		858,	1132,	5869]

mono_TP     = [30.44,	50.42,	58.51,	66.46,	73.77,	80.67,	86.42,	86.92,	85.86]
mono_med    = [63,	69,	104,	141,	182,	266,	345,	414,	427]
mono_p95    = [103,	180,	236,	288,	352,	401,	452,	546,	584]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(micro_TP[:-1], micro_med[:-1], color='orange', marker='o', linestyle='-', label="Microservices median")
plt.plot(mono_TP[:-1], mono_med[:-1], color='blue', marker='o', linestyle='-', label="Monolithic median")

plt.plot(micro_TP[:-1], micro_p95[:-1], color='orange', marker='v', linestyle='--', label="Microservices p95")
plt.plot(mono_TP[:-1], mono_p95[:-1], color='blue', marker='v', linestyle='--', label="Monolithic p95")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Latency (ms)")
plt.title("Latency Comparison: Micro vs. Mono deployment on $\mathbf{Ray}$ with 4 nodes")
plt.grid(True)
plt.legend()

plt.savefig('./latency_microVSmono_cluster4ray.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
node_hr = 4.352

micro_QPH = [a*3600 for a in micro_TP]
mono_QPH = [b*3600 for b in mono_TP]
micro_cpq = [node_hr/x for x in micro_QPH]
mono_cpq = [node_hr/y for y in mono_QPH]
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(micro_TP, micro_cpq, color='orange', marker='o', linestyle='-', label="Microservices")
plt.plot(mono_TP, mono_cpq, color='blue', marker='o', linestyle='-', label="Monolithic")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Cost per query ($)")
plt.title("Cost Per Query: Micro vs. Mono deployment on $\mathbf{Ray}$ with 4 nodes")
plt.grid(True)
plt.legend()
plt.savefig('./cpq_microVSmono_cluster4ray.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### TP vs Lat cluster 7 Vortex

# %%
node_hr = 4.352

micro_TP    = [61.983,	131.805,	147.187,	163.943,	179.32,	202.797,	215.659,	218.033,	217.752,	215.651]
mono_TP     = [31.715,	130.614,	147.562,	163.303,	178.377,	181.969,	182.228]

micro_QPH = [a*3600 for a in micro_TP]
mono_QPH = [b*3600 for b in mono_TP]
micro_cpq = [node_hr/x for x in micro_QPH]
mono_cpq = [node_hr/y for y in mono_QPH]
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(micro_TP[:-2], micro_cpq[:-2], color='red', marker='o', linestyle='-', label="Microservices")
plt.plot(mono_TP[:-2], mono_cpq[:-2], color='green', marker='o', linestyle='-', label="Monolithic")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Cost per query ($)")
plt.title("Cost Per Query: Micro vs. Mono deployment on $\mathbf{Vortex}$ with 7 nodes")
plt.grid(True)
plt.legend()
plt.savefig('./cpq_microVSmono_cluster7vortex.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
micro_TP    = [61.983,	131.805,	147.187,	163.943,	179.32,	202.797,	215.659,	218.033,	217.752,	215.651]
micro_med   = [69.949,	69.182,	69.275,	98,	119.988,	365.897,	549.633,	1734.611,	1902.142,	2382.035]
micro_p95   = [79.133,	79.715,	81.957,	155.555,157.413	,480.464,	812.796,	2703.697,	2913.155,	3922.299]

mono_TP     = [31.715,	94.789,	130.614,	147.562,	163.303,	178.377,	181.969,	182.228]
mono_med    = [75.178,	57.821,	105.227,	141.165,	260.555,	529.825,	1575.772,	2830.595]
mono_p95    = [82.561,	60.791,	152.574,	189.121,	425.181,	789.211,	2775.171,	4794.318]

# %%
plt.figure(figsize=(8, 6))
plt.plot(micro_TP[:-2], micro_med[:-2], color='red', marker='o', linestyle='-', label="Microservices median")
plt.plot(mono_TP[:-2], mono_med[:-2], color='green', marker='o', linestyle='-', label="Monolithic median")

plt.plot(micro_TP[:-2], micro_p95[:-2], color='red', marker='v', linestyle='--', label="Microservices p95")
plt.plot(mono_TP[:-2], mono_p95[:-2], color='green', marker='v', linestyle='--', label="Monolithic p95")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Latency (ms)")
plt.title("Latency Comparison: Micro vs. Mono deployment on $\mathbf{Vortex}$ with 7 nodes")
plt.grid(True)
plt.legend()

plt.savefig('./latency_microVSmono_cluster7vortex.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
node_hr = 4.352

micro_TP    = [58,	114.07,	127.09,	138.15,	170.72,	184.81,	196.6,	209.73,	214.22,	197.86]
mono_TP     = [30.44,	85.62,	112.45,	124.75,	135.66,	144.55,	152.14,	148.39]


micro_QPH = [a*3600 for a in micro_TP]
mono_QPH = [b*3600 for b in mono_TP]
micro_cpq = [node_hr/x for x in micro_QPH]
mono_cpq = [node_hr/y for y in mono_QPH]
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(micro_TP, micro_cpq, color='blue', marker='o', linestyle='-', label="Microservices")
plt.plot(mono_TP, mono_cpq, color='orange', marker='o', linestyle='-', label="Monolithic")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Cost per query ($)")
plt.title("Cost Per Query: Micro vs. Mono deployment on $\mathbf{Ray}$ with 7 nodes")
plt.grid(True)
plt.legend()
plt.savefig('./cpq_microVSmono_cluster7ray.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
micro_TP    = [58,	114.07,	127.09,	138.15,	170.72,	184.81,	196.6,	209.73,	214.22,	197.86]
micro_med   = [104,	156,	178,	206,	312,	428,	595,	788,	1019,	3183.5]
micro_p95   = [151,	334,	389,	566,	666,	843,	1040,	1185,	1419,	8059]

mono_TP     = [30.44,	85.62,	112.45,	124.75,	135.66,	144.55,	152.14,	148.39]
mono_med    = [65,	68,	115,	150,	231,	299,	347,	427]
mono_p95    = [83,	189,	310,	351,	406,	427,	480,	518]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(micro_TP, micro_med, color='orange', marker='o', linestyle='-', label="Microservices median")
plt.plot(mono_TP, mono_med, color='blue', marker='o', linestyle='-', label="Monolithic median")

plt.plot(micro_TP, micro_p95, color='orange', marker='v', linestyle='--', label="Microservices p95")
plt.plot(mono_TP, mono_p95, color='blue', marker='v', linestyle='--', label="Monolithic p95")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Latency (ms)")
plt.title("Latency Comparison: Micro vs. Mono deployment on $\mathbf{Ray}$ with 7 nodes")
plt.grid(True)
plt.legend()

plt.savefig('./latency_microVSmono_cluster7ray.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.plot(micro_TP[:-1], micro_med[:-1], color='orange', marker='o', linestyle='-', label="Microservices median")
plt.plot(mono_TP[:-1], mono_med[:-1], color='blue', marker='o', linestyle='-', label="Monolithic median")

plt.plot(micro_TP[:-1], micro_p95[:-1], color='orange', marker='v', linestyle='--', label="Microservices p95")
plt.plot(mono_TP[:-1], mono_p95[:-1], color='blue', marker='v', linestyle='--', label="Monolithic p95")
plt.xlabel("System Throughput (QPS)")
plt.ylabel("Latency (ms)")
plt.title("Latency Comparison: Micro vs. Mono deployment on $\mathbf{Ray}$ with 7 nodes")
plt.grid(True)
plt.legend()

plt.savefig('./latency_microVSmono_cluster7ray.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
micro_TP    = []
micro_med   = []
micro_p95   = []

mono_TP     = []
mono_med    = []
mono_p95    = []
